# %% [markdown]
# # To do:
#
# Tentar usar um gráfo mais simplificado

# %%
import osmnx as ox
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Get the graph of Porto
city = ox.geocode_to_gdf('Porto, Portugal')
G = ox.graph_from_polygon(city.geometry.iloc[0], network_type='walk')

# %%
# Get the places of worship in Porto
tags = {'amenity': 'place_of_worship'}
churches = ox.features_from_polygon(city.geometry.iloc[0], tags)

# %%
churches.head()
# Out:
#                                               alt_name           amenity  \
# element_type osmid
# node         2210643419  Capela Nossa Senhora da Silva  place_of_worship
#              2469033332                            NaN  place_of_worship
#              4395076911                            NaN  place_of_worship
#              4554574479                            NaN  place_of_worship
#              4716522744                            NaN  place_of_worship
#
#                              denomination  \
# element_type osmid
# node         2210643419    roman_catholic
#              2469033332    roman_catholic
#              4395076911  jehovahs_witness
#              4554574479  jehovahs_witness
#              4716522744  jehovahs_witness
#
#                                                      heritage:website:sipa  \
# element_type osmid
# node         2210643419  http://www.monumentos.gov.pt/Site/APP_PagesUse...
#              2469033332  http://www.monumentos.gov.pt/Site/APP_PagesUse...
#              4395076911                                                NaN
#              4554574479                                                NaN
#              4716522744                                                NaN
#
#                                                             name ref:ipa  \
# element_type osmid
# node         2210643419       Oratório de Nossa Senhora da Silva    5498
#              2469033332                        Alminhas da Ponte    5539
#              4395076911  Salão do Reino das Testemunhas de Jeová     NaN
#              4554574479  Salão do Reino das Testemunhas de Jeová     NaN
#              4716522744  Salão do Reino das Testemunhas de Jeová     NaN
#
#                           religion                   geometry  \
# element_type osmid
# node         2210643419  christian  POINT (-8.61326 41.14540)
#              2469033332  christian  POINT (-8.61103 41.14071)
#              4395076911  christian  POINT (-8.56673 41.16373)
#              4554574479  christian  POINT (-8.60869 41.14215)
#              4716522744  christian  POINT (-8.62310 41.14941)
#
#                         addr:housenumber          addr:street  ...  \
# element_type osmid                                             ...
# node         2210643419              NaN                  NaN  ...
#              2469033332              NaN      Cais da Ribeira  ...
#              4395076911              NaN                  NaN  ...
#              4554574479              NaN                  NaN  ...
#              4716522744              538  Rua Miguel Bombarda  ...
#
#                         contact:website roof:material roof:orientation  \
# element_type osmid
# node         2210643419             NaN           NaN              NaN
#              2469033332             NaN           NaN              NaN
#              4395076911             NaN           NaN              NaN
#              4554574479             NaN           NaN              NaN
#              4716522744             NaN           NaN              NaN
#
#                         addr:housename patron_saint event_annual landuse area  \
# element_type osmid
# node         2210643419            NaN          NaN          NaN     NaN  NaN
#              2469033332            NaN          NaN          NaN     NaN  NaN
#              4395076911            NaN          NaN          NaN     NaN  NaN
#              4554574479            NaN          NaN          NaN     NaN  NaN
#              4716522744            NaN          NaN          NaN     NaN  NaN
#
#                         ways type
# element_type osmid
# node         2210643419  NaN  NaN
#              2469033332  NaN  NaN
#              4395076911  NaN  NaN
#              4554574479  NaN  NaN
#              4716522744  NaN  NaN
#
# [5 rows x 108 columns]

# %% [markdown]
# É agora necessário escolher só algumas igrejas, verificando se existem no conjunto de dados:

# %%
print(sum(churches['name'] == "Sé do Porto"))
print(sum(churches['name'] == "Igreja do Carmo"))
print(sum(churches['name'] == "Igreja dos Carmelitas"))
print(sum(churches['name'] == "Igreja da Lapa"))
print(sum(churches['name'] == "Igreja de São Francisco"))
print(sum(churches['name'] == "Igreja de Santa Clara"))
print(sum(churches['name'] == "Igreja de Nossa Senhora da Conceição"))
print(sum(churches['name'] == "Igreja do Senhor do Bonfim"))
print(sum(churches['name'] == "Igreja Paroquial de Santo Ildefonso"))
print(sum(churches['name'] == "Igreja dos Clérigos"))
# Out:
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 2

# %% [markdown]
# estranhamente existem duas igrejas dos Clérigos, filtrando o conjunto de dados

# %%
selected_names = [
    "Sé do Porto",
    "Igreja do Carmo",
    "Igreja dos Carmelitas",
    "Igreja da Lapa",
    "Igreja de São Francisco",
    "Igreja de Santa Clara",
    "Igreja de Nossa Senhora da Conceição",
    "Igreja do Senhor do Bonfim",
    "Igreja Paroquial de Santo Ildefonso",
    "Igreja dos Clérigos"
]

# Filter the DataFrame for the selected church names
filtered_churches = churches[churches['name'].isin(selected_names)]

filtered_churches
# Out:
#                                                                  alt_name  \
# element_type osmid
# way          128828528                                                NaN
#              210461448  Catedral do Porto;Sé Catedral;Sé Catedral do P...
#              210681249                Igreja do Convento de São Francisco
#              211337881                                                NaN
#              213578739                          Igreja de Santo Ildefonso
#              223780953                   Igreja de São Pedro dos Clérigos
#              227716463  Igreja da Senhora da Conceição; Igreja da Noss...
#              229772731  Igreja da Venerável Ordem Terceira de Nossa Se...
#              229772732                    Igreja dos Carmelitas Descalços
#              238893532  Igreja do Dispensário Rainha Dona Amélia; Igre...
#              391839915                                                NaN
#
#                                  amenity    denomination  \
# element_type osmid
# way          128828528  place_of_worship  roman_catholic
#              210461448  place_of_worship  roman_catholic
#              210681249  place_of_worship  roman_catholic
#              211337881  place_of_worship             NaN
#              213578739  place_of_worship  roman_catholic
#              223780953  place_of_worship  roman_catholic
#              227716463  place_of_worship  roman_catholic
#              229772731  place_of_worship  roman_catholic
#              229772732  place_of_worship  roman_catholic
#              238893532  place_of_worship  roman_catholic
#              391839915  place_of_worship  roman_catholic
#
#                                                     heritage:website:sipa  \
# element_type osmid
# way          128828528  http://www.monumentos.gov.pt/Site/APP_PagesUse...
#              210461448  http://www.monumentos.gov.pt/Site/APP_PagesUse...
#              210681249  http://monumentos.pt/Site/APP_PagesUser/SIPA.a...
#              211337881  http://monumentos.pt/Site/APP_PagesUser/SIPA.a...
#              213578739  www.monumentos.gov.pt/Site/APP_PagesUser/SIPA....
#              223780953                                                NaN
#              227716463  http://www.monumentos.gov.pt/Site/APP_PagesUse...
#              229772731  http://www.monumentos.gov.pt/Site/APP_PagesUse...
#              229772732  http://www.monumentos.gov.pt/Site/APP_PagesUse...
#              238893532  http://www.monumentos.gov.pt/Site/APP_PagesUse...
#              391839915                                                NaN
#
#                                                         name ref:ipa  \
# element_type osmid
# way          128828528                        Igreja da Lapa   15547
#              210461448                           Sé do Porto    1086
#              210681249               Igreja de São Francisco    3944
#              211337881                   Igreja dos Clérigos    5522
#              213578739   Igreja Paroquial de Santo Ildefonso    5464
#              223780953                   Igreja dos Clérigos     NaN
#              227716463  Igreja de Nossa Senhora da Conceição    5574
#              229772731                       Igreja do Carmo    5521
#              229772732                 Igreja dos Carmelitas    5497
#              238893532                 Igreja de Santa Clara    9341
#              391839915            Igreja do Senhor do Bonfim     NaN
#
#                          religion  \
# element_type osmid
# way          128828528  christian
#              210461448  christian
#              210681249  christian
#              211337881  christian
#              213578739  christian
#              223780953  christian
#              227716463  christian
#              229772731  christian
#              229772732  christian
#              238893532  christian
#              391839915  christian
#
#                                                                  geometry  \
# element_type osmid
# way          128828528  POLYGON ((-8.61237 41.15724, -8.61235 41.15721...
#              210461448  POLYGON ((-8.61119 41.14287, -8.61119 41.14293...
#              210681249  POLYGON ((-8.61601 41.14104, -8.61601 41.14102...
#              211337881  POLYGON ((-8.61388 41.14592, -8.61388 41.14592...
#              213578739  POLYGON ((-8.60661 41.14606, -8.60643 41.14623...
#              223780953  POLYGON ((-8.61420 41.14570, -8.61412 41.14572...
#              227716463  POLYGON ((-8.60559 41.16133, -8.60562 41.16128...
#              229772731  POLYGON ((-8.61617 41.14733, -8.61626 41.14733...
#              229772732  POLYGON ((-8.61634 41.14732, -8.61636 41.14732...
#              238893532  POLYGON ((-8.60944 41.14251, -8.60937 41.14262...
#              391839915  POLYGON ((-8.59312 41.15131, -8.59273 41.15154...
#
#                        addr:housenumber                  addr:street  ...  \
# element_type osmid                                                    ...
# way          128828528              NaN                          NaN  ...
#              210461448              NaN                          NaN  ...
#              210681249              NaN  Rua do Infante Dom Henrique  ...
#              211337881              NaN    Rua de São Filipe de Nery  ...
#              213578739         4000-101       Rua de Santo Ildefonso  ...
#              223780953              NaN    Rua de São Filipe de Nery  ...
#              227716463              111   Praça do Marquês de Pombal  ...
#              229772731              NaN                 Rua do Carmo  ...
#              229772732              NaN                          NaN  ...
#              238893532              155   Largo Primeiro de Dezembro  ...
#              391839915              NaN                          NaN  ...
#
#                        contact:website roof:material roof:orientation  \
# element_type osmid
# way          128828528             NaN           NaN              NaN
#              210461448             NaN           NaN              NaN
#              210681249             NaN           NaN              NaN
#              211337881             NaN           NaN              NaN
#              213578739             NaN           NaN              NaN
#              223780953             NaN           NaN              NaN
#              227716463             NaN           NaN              NaN
#              229772731             NaN           NaN              NaN
#              229772732             NaN           NaN              NaN
#              238893532             NaN           NaN              NaN
#              391839915             NaN           NaN              NaN
#
#                        addr:housename patron_saint event_annual landuse area  \
# element_type osmid
# way          128828528            NaN          NaN          NaN     NaN  NaN
#              210461448            NaN          NaN          NaN     NaN  NaN
#              210681249            NaN          NaN          NaN     NaN  NaN
#              211337881            NaN          NaN          NaN     NaN  NaN
#              213578739            NaN          NaN          NaN     NaN  NaN
#              223780953            NaN          NaN          NaN     NaN  NaN
#              227716463            NaN          NaN          NaN     NaN  NaN
#              229772731            NaN          NaN          NaN     NaN  NaN
#              229772732            NaN          NaN          NaN     NaN  NaN
#              238893532            NaN          NaN          NaN     NaN  NaN
#              391839915            NaN          NaN          NaN     NaN  NaN
#
#                        ways type
# element_type osmid
# way          128828528  NaN  NaN
#              210461448  NaN  NaN
#              210681249  NaN  NaN
#              211337881  NaN  NaN
#              213578739  NaN  NaN
#              223780953  NaN  NaN
#              227716463  NaN  NaN
#              229772731  NaN  NaN
#              229772732  NaN  NaN
#              238893532  NaN  NaN
#              391839915  NaN  NaN
#
# [11 rows x 108 columns]

# %% [markdown]
# e removendo a linha repetida

# %%
# Remove duplicate entries for 'Igreja dos Clérigos'
filtered_churches = filtered_churches.drop_duplicates(subset='name', keep='first')

filtered_churches
# Out:
#                                                                  alt_name  \
# element_type osmid
# way          128828528                                                NaN
#              210461448  Catedral do Porto;Sé Catedral;Sé Catedral do P...
#              210681249                Igreja do Convento de São Francisco
#              211337881                                                NaN
#              213578739                          Igreja de Santo Ildefonso
#              227716463  Igreja da Senhora da Conceição; Igreja da Noss...
#              229772731  Igreja da Venerável Ordem Terceira de Nossa Se...
#              229772732                    Igreja dos Carmelitas Descalços
#              238893532  Igreja do Dispensário Rainha Dona Amélia; Igre...
#              391839915                                                NaN
#
#                                  amenity    denomination  \
# element_type osmid
# way          128828528  place_of_worship  roman_catholic
#              210461448  place_of_worship  roman_catholic
#              210681249  place_of_worship  roman_catholic
#              211337881  place_of_worship             NaN
#              213578739  place_of_worship  roman_catholic
#              227716463  place_of_worship  roman_catholic
#              229772731  place_of_worship  roman_catholic
#              229772732  place_of_worship  roman_catholic
#              238893532  place_of_worship  roman_catholic
#              391839915  place_of_worship  roman_catholic
#
#                                                     heritage:website:sipa  \
# element_type osmid
# way          128828528  http://www.monumentos.gov.pt/Site/APP_PagesUse...
#              210461448  http://www.monumentos.gov.pt/Site/APP_PagesUse...
#              210681249  http://monumentos.pt/Site/APP_PagesUser/SIPA.a...
#              211337881  http://monumentos.pt/Site/APP_PagesUser/SIPA.a...
#              213578739  www.monumentos.gov.pt/Site/APP_PagesUser/SIPA....
#              227716463  http://www.monumentos.gov.pt/Site/APP_PagesUse...
#              229772731  http://www.monumentos.gov.pt/Site/APP_PagesUse...
#              229772732  http://www.monumentos.gov.pt/Site/APP_PagesUse...
#              238893532  http://www.monumentos.gov.pt/Site/APP_PagesUse...
#              391839915                                                NaN
#
#                                                         name ref:ipa  \
# element_type osmid
# way          128828528                        Igreja da Lapa   15547
#              210461448                           Sé do Porto    1086
#              210681249               Igreja de São Francisco    3944
#              211337881                   Igreja dos Clérigos    5522
#              213578739   Igreja Paroquial de Santo Ildefonso    5464
#              227716463  Igreja de Nossa Senhora da Conceição    5574
#              229772731                       Igreja do Carmo    5521
#              229772732                 Igreja dos Carmelitas    5497
#              238893532                 Igreja de Santa Clara    9341
#              391839915            Igreja do Senhor do Bonfim     NaN
#
#                          religion  \
# element_type osmid
# way          128828528  christian
#              210461448  christian
#              210681249  christian
#              211337881  christian
#              213578739  christian
#              227716463  christian
#              229772731  christian
#              229772732  christian
#              238893532  christian
#              391839915  christian
#
#                                                                  geometry  \
# element_type osmid
# way          128828528  POLYGON ((-8.61237 41.15724, -8.61235 41.15721...
#              210461448  POLYGON ((-8.61119 41.14287, -8.61119 41.14293...
#              210681249  POLYGON ((-8.61601 41.14104, -8.61601 41.14102...
#              211337881  POLYGON ((-8.61388 41.14592, -8.61388 41.14592...
#              213578739  POLYGON ((-8.60661 41.14606, -8.60643 41.14623...
#              227716463  POLYGON ((-8.60559 41.16133, -8.60562 41.16128...
#              229772731  POLYGON ((-8.61617 41.14733, -8.61626 41.14733...
#              229772732  POLYGON ((-8.61634 41.14732, -8.61636 41.14732...
#              238893532  POLYGON ((-8.60944 41.14251, -8.60937 41.14262...
#              391839915  POLYGON ((-8.59312 41.15131, -8.59273 41.15154...
#
#                        addr:housenumber                  addr:street  ...  \
# element_type osmid                                                    ...
# way          128828528              NaN                          NaN  ...
#              210461448              NaN                          NaN  ...
#              210681249              NaN  Rua do Infante Dom Henrique  ...
#              211337881              NaN    Rua de São Filipe de Nery  ...
#              213578739         4000-101       Rua de Santo Ildefonso  ...
#              227716463              111   Praça do Marquês de Pombal  ...
#              229772731              NaN                 Rua do Carmo  ...
#              229772732              NaN                          NaN  ...
#              238893532              155   Largo Primeiro de Dezembro  ...
#              391839915              NaN                          NaN  ...
#
#                        contact:website roof:material roof:orientation  \
# element_type osmid
# way          128828528             NaN           NaN              NaN
#              210461448             NaN           NaN              NaN
#              210681249             NaN           NaN              NaN
#              211337881             NaN           NaN              NaN
#              213578739             NaN           NaN              NaN
#              227716463             NaN           NaN              NaN
#              229772731             NaN           NaN              NaN
#              229772732             NaN           NaN              NaN
#              238893532             NaN           NaN              NaN
#              391839915             NaN           NaN              NaN
#
#                        addr:housename patron_saint event_annual landuse area  \
# element_type osmid
# way          128828528            NaN          NaN          NaN     NaN  NaN
#              210461448            NaN          NaN          NaN     NaN  NaN
#              210681249            NaN          NaN          NaN     NaN  NaN
#              211337881            NaN          NaN          NaN     NaN  NaN
#              213578739            NaN          NaN          NaN     NaN  NaN
#              227716463            NaN          NaN          NaN     NaN  NaN
#              229772731            NaN          NaN          NaN     NaN  NaN
#              229772732            NaN          NaN          NaN     NaN  NaN
#              238893532            NaN          NaN          NaN     NaN  NaN
#              391839915            NaN          NaN          NaN     NaN  NaN
#
#                        ways type
# element_type osmid
# way          128828528  NaN  NaN
#              210461448  NaN  NaN
#              210681249  NaN  NaN
#              211337881  NaN  NaN
#              213578739  NaN  NaN
#              227716463  NaN  NaN
#              229772731  NaN  NaN
#              229772732  NaN  NaN
#              238893532  NaN  NaN
#              391839915  NaN  NaN
#
# [10 rows x 108 columns]

# %% [markdown]
# # Calculando a matriz de distâncias

# %%
def calculate_distance_matrix(gdf, G):
    """
    Calculate the distance matrix for a set of objects within a GeoDataFrame using a specified road network graph.

    Parameters:
    gdf (GeoDataFrame): A GeoPandas GeoDataFrame containing the objects with their geographic data.
                        The GeoDataFrame must have an 'index' with unique identifiers for each object
                        and a 'geometry' column with Point geometries.
    G (Graph): An OSMnx graph representing the road network.

    Returns:
    DataFrame: A pandas DataFrame representing the distance matrix, where each cell [i, j]
               contains the shortest path length between object i and object j.
    """
    # Initialize an empty matrix
    dist_matrix = pd.DataFrame(index=gdf.index, columns=gdf.index)

    # Fill the diagonal with zeros
    np.fill_diagonal(dist_matrix.values, 0)

    for i in gdf.index:
        for j in gdf.index:
            if i != j:
                # Get the shortest path between the two nodes
                origin = (gdf.loc[i, 'geometry'].centroid.y, gdf.loc[i, 'geometry'].centroid.x)
                destination = (gdf.loc[j, 'geometry'].centroid.y, gdf.loc[j, 'geometry'].centroid.x)
                orig_node = ox.nearest_nodes(G, origin[1], origin[0])
                dest_node = ox.nearest_nodes(G, destination[1], destination[0])
                try:
                    shortest_path = nx.shortest_path_length(G, orig_node, dest_node, weight='length')
                    dist_matrix.loc[i, j] = shortest_path
                except nx.NetworkXNoPath:
                    dist_matrix.loc[i, j] = float('inf')

    return dist_matrix

# Example usage:
# Assuming 'gdf' is your GeoDataFrame with the selected objects and their geometries
# 'G' is your graph object from OSMnx
# distance_matrix = calculate_distance_matrix(gdf, G)

# %%
dist_matrix = calculate_distance_matrix(filtered_churches, G)

dist_matrix
# Out:
# element_type                 way                                          \
# osmid                  128828528 210461448 210681249 211337881 213578739
# element_type osmid
# way          128828528         0  1670.296  2012.253  1405.595   1604.88
#              210461448  1670.296         0    655.64   584.176   588.851
#              210681249  2012.253    655.64         0    827.04  1161.856
#              211337881  1405.595   584.176    827.04         0    939.41
#              213578739   1604.88   588.851  1161.856    939.41         0
#              227716463    980.55  2414.804  2842.521  2261.255   1986.29
#              229772731  1199.966   813.365  1008.954   322.788   1093.32
#              229772732  1199.966   813.365  1008.954   322.788   1093.32
#              238893532  1876.153   329.195   956.171   845.471   624.003
#              391839915  2186.032  1911.788  2484.793   2132.99  1364.576
#
# element_type
# osmid                  227716463 229772731 229772732 238893532 391839915
# element_type osmid
# way          128828528    980.55  1199.966  1199.966  1876.153  2186.032
#              210461448  2414.804   813.365   813.365   329.195  1911.788
#              210681249  2842.521  1008.954  1008.954   956.171  2484.793
#              211337881  2261.255   322.788   322.788   845.471   2132.99
#              213578739   1986.29   1093.32   1093.32   624.003  1364.576
#              227716463         0   2135.73   2135.73  2484.935   1879.36
#              229772731   2135.73         0         0   1074.66  2230.185
#              229772732   2135.73         0         0   1074.66  2230.185
#              238893532  2484.935   1074.66   1074.66         0  1844.259
#              391839915   1879.36  2230.185  2230.185  1844.259         0

# %%
# Save the distance matrix to a CSV file
dist_matrix.to_csv('distance_matrix.csv')

# %%
# Plot the street network
fig, ax = ox.plot_graph(G, show=False, close=False)

# %%
filtered_churches.plot()
# Out:
# <Axes: >

# %% [markdown]
# # Representing a route of the data

# %%
dist_matrix = pd.read_csv('distance_matrix.csv')

# %%
# Plot the route between two churches
church1, church2 = churches.index[0], churches.index[1]  # Replace with your churches
origin = (churches.loc[church1, 'geometry'].centroid.y, churches.loc[church1, 'geometry'].centroid.x)
destination = (churches.loc[church2, 'geometry'].centroid.y, churches.loc[church2, 'geometry'].centroid.x)
orig_node = ox.nearest_nodes(G, origin[1], origin[0])
dest_node = ox.nearest_nodes(G, destination[1], destination[0])
shortest_path = nx.shortest_path(G, orig_node, dest_node, weight='length')
fig, ax = ox.plot_graph_route(G, shortest_path, node_size=0)
plt.show()

# %%
# List of indices
indices = [0, 1, 2, 3, 4, 5, 0]

# Initialize an empty list to store the nodes of the route
route = []

for i in range(len(indices) - 1):
    index = indices[i]
    church1, church2 = churches.index[index], churches.index[index+1]
    origin = (churches.loc[church1, 'geometry'].centroid.y, churches.loc[church1, 'geometry'].centroid.x)
    destination = (churches.loc[church2, 'geometry'].centroid.y, churches.loc[church2, 'geometry'].centroid.x)
    orig_node = ox.nearest_nodes(G, origin[1], origin[0])
    dest_node = ox.nearest_nodes(G, destination[1], destination[0])
    shortest_path = nx.shortest_path(G, orig_node, dest_node, weight='length')
    route.extend(shortest_path[:-1])  # Exclude the last node because it will be included in the next path

# Add the last node of the last path
route.append(shortest_path[-1])

# Plot the route
fig, ax = ox.plot_graph_route(G, route, node_size=0)
plt.show()

# %%
indices = [0,11,43,41,40,42,48,49,27,18,7,21,23,10,9,
           24,17,19,4,25,14,26,16,13,20,15,22,2,12,5,
           6,8,44,46,47,45,3,32,29,28,30,31,33,1,34,
           35,36,37,38,39]

# Initialize an empty list to store the nodes of the route
route = []

for i in range(len(indices) - 1):
    index = indices[i]
    church1, church2 = churches.index[index], churches.index[index+1]
    origin = (churches.loc[church1, 'geometry'].centroid.y, churches.loc[church1, 'geometry'].centroid.x)
    destination = (churches.loc[church2, 'geometry'].centroid.y, churches.loc[church2, 'geometry'].centroid.x)
    orig_node = ox.nearest_nodes(G, origin[1], origin[0])
    dest_node = ox.nearest_nodes(G, destination[1], destination[0])
    shortest_path = nx.shortest_path(G, orig_node, dest_node, weight='length')
    route.extend(shortest_path[:-1])  # Exclude the last node because it will be included in the next path

# Add the last node of the last path
route.append(shortest_path[-1])

# %%
indices = [0,11,43,41,40,42,48,49,27,18,7,21,23,10,9,
           24,17,19,4,25,14,26,16,13,20,15,22,2,12,5,
           6,8,44,46,47,45,3,32,29,28,30,31,33,1,34,
           35,36,37,38,39]

# Assuming 'G' is your graph and 'indices' is your list of indices
route = []
for i in range(len(indices) - 1):
    index = indices[i]
    church1, church2 = churches.index[index], churches.index[index+1]
    origin = (churches.loc[church1, 'geometry'].centroid.y, churches.loc[church1, 'geometry'].centroid.x)
    destination = (churches.loc[church2, 'geometry'].centroid.y, churches.loc[church2, 'geometry'].centroid.x)
    orig_node = ox.nearest_nodes(G, origin[1], origin[0])
    dest_node = ox.nearest_nodes(G, destination[1], destination[0])
    
    # Check if a path exists
    if nx.has_path(G, orig_node, dest_node):
        shortest_path = nx.shortest_path(G, orig_node, dest_node, weight='length')
        route.extend(shortest_path[:-1])  # Exclude the last node because it will be included in the next path
    else:
        print(f"No path found between nodes {orig_node} and {dest_node}")

# Add the last node of the last path
route.append(shortest_path[-1])

# %%
indices = [0, 11, 43, 41, 40, 42,48, 49,
           27, 18, 7, 21,23, 10, 9, 24, 
           17, 19, 4, 25, 14, 26, 16, 13,
           20,15, 22, 2, 12, 5, 6, 8, 44, 
           46, 47, 45, 3, 32, 29, 28, 30, 
           31, 33, 1, 34, 35, 36, 37, 38, 39]

# Assuming 'G' is your graph and 'indices' is your list of indices
route = []
for i in range(len(indices)):
    index = indices[i]
    church1, church2 = churches.index[index], churches.index[index+1]
    origin = (churches.loc[church1, 'geometry'].centroid.y, churches.loc[church1, 'geometry'].centroid.x)
    destination = (churches.loc[church2, 'geometry'].centroid.y, churches.loc[church2, 'geometry'].centroid.x)
    orig_node = ox.nearest_nodes(G, origin[1], origin[0])
    dest_node = ox.nearest_nodes(G, destination[1], destination[0])
    
    # Check if a path exists
    if nx.has_path(G, orig_node, dest_node):
        shortest_path = nx.shortest_path(G, orig_node, dest_node, weight='length')
        #route.extend(shortest_path[:-1])  # Exclude the last node because it will be included in the next path
        route.extend(shortest_path)
    else:
        print(f"No path found between nodes {orig_node} and {dest_node}")

# Add the last path
shortest_path = nx.shortest_path(G, route[-1], route[0], weight='length')
route.append(shortest_path)

# %%
# Plot the route
fig, ax = ox.plot_graph_route(G, route[1:25], node_size=0)
plt.show()

# %%
import matplotlib.colors as mcolors

# Create a color map that goes from green to red
cmap = mcolors.LinearSegmentedColormap.from_list("mycmap", ["green", "red"])

fig, ax = ox.plot_graph(G, node_size=0, show=False, close=False)

# Divide the route into pairs and plot them one at a time
for i in range(20 - 1):
    pair = route[i:i+2]
    color = cmap(i / len(route))  # Get color from color map
    ox.plot_graph_route(G, pair, route_color=color, route_linewidth=6, orig_dest_node_size=100, ax=ax)

plt.show()
# Out:
# /opt/conda/lib/python3.11/site-packages/osmnx/plot.py:327: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(x, y, s=orig_dest_size, c=route_color, alpha=route_alpha, edgecolor="none")

# %% [markdown]
# # Methods aplication
